# %% [markdown]
# # CSIRO Feeder Screening
#
# ### Goal:
# - Scan CSIRO feeders (https://data.csiro.au/collection/csiro:62996)
# - Identify small, interpretable radial networks
# - Select a feeder suitable for baseline EV experiments

# %% [markdown]
# ## Screening- Four-wire feeders

# %%
using PowerModelsDistribution
using DataFrames

BASE_DIR = joinpath("..", "data", "Four-wire")

results = DataFrame(
    network = String[],
    feeder = String[],
    buses = Int[],
    loads = Int[],
    branches = Int[]
)

for net in sort(readdir(BASE_DIR))
    net_path = joinpath(BASE_DIR, net)
    isdir(net_path) || continue

    for feeder in sort(readdir(net_path))
        feeder_path = joinpath(net_path, feeder)
        master = joinpath(feeder_path, "Master.dss")

        isfile(master) || continue

        try
            pm = PowerModelsDistribution.parse_file(master)

            n_buses = length(pm["bus"])
            n_loads = haskey(pm, "load") ? length(pm["load"]) : 0
            n_lines = haskey(pm, "line") ? length(pm["line"]) : 0
            n_transformers = haskey(pm, "transformer") ? length(pm["transformer"]) : 0

            push!(results, (
                net,
                feeder,
                n_buses,
                n_loads,
                n_lines + n_transformers
            ))
        catch e
            @warn "Failed to load $net / $feeder"
        end
    end
end

results
# Out:
# [ PowerModelsDistribution | Info ] : Circuit has been reset with the 'clear' on line 18 in 'Master.dss'
# [ PowerModelsDistribution | Info ] : Redirecting to 'linecode.txt' on line 23 in 'Master.dss'
# [ PowerModelsDistribution | Info ] : Redirecting to 'lines.txt' on line 24 in 'LineCode.txt'
# [ PowerModelsDistribution | Info ] : Redirecting to 'loads.txt' on line 25 in 'Lines.txt'
# [ PowerModelsDistribution | Info ] : Command 'solve' on line 30 in 'Master.dss' is not supported, skipping.
# [ PowerModelsDistribution | Info ] : Command 'closedi' on line 31 in 'Master.dss' is not supported, skipping.
# [ PowerModelsDistribution | Info ] : basemva=100 is the default value, you may want to adjust sbase_default for better convergence
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line865 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line617 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line991 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line821 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line722 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line120 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line330 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line902 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1764 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1214 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line535 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1066 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1890 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2115 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2249 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1631 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2274 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1515 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2096 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line929 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line698 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line551 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line830 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1755 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2217 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line329 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2313 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1332 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1215 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line117 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line851 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1433 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2187 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1884 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line470 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2089 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1516 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line502 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1389 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1342 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2345 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2051 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line609 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line992 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1083 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1413 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2259 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1345 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line736 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line947 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2330 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2335 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1446 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1281 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line537 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line242 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1720 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1473 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1938 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2201 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1173 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1363 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1578 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1621 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line298 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line639 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line428 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line608 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1056 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1053 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line733 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2198 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line83 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1331 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1408 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1564 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line247 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line548 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1989 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line13 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line213 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line709 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2046 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line440 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2175 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line496 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line974 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line122 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line876 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line423 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line871 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1699 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2047 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2050 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line232 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1065 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1189 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1550 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line529 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1999 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2154 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line840 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1097 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line158 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1701 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1439 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line21 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1543 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1958 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line373 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line7 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line74 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line514 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line751 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1480 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line142 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1945 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1226 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1723 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1080 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1330 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2191 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line151 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1217 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1911 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1293 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1635 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1601 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line143 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line636 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line670 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line342 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1444 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1964 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2232 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line652 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line403 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line462 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line301 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line626 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line846 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1245 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2302 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line766 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2058 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1423 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1287 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line261 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line930 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line64 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2334 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1016 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2347 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1659 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line315 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line385 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1494 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line605 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line188 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1429 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1882 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2136 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2270 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2056 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line799 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line625 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1848 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2337 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1808 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line132 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line45 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1919 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1170 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1365 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line490 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1367 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line228 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1910 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1007 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1642 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line664 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line572 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1375 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line538 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line591 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line159 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line906 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1121 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1749 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line383 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1602 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2262 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line260 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2214 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2040 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line895 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1055 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line898 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line850 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line760 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line925 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1166 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1852 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2304 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line238 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line172 does not match circuit basefreq=50.0
# ...
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line881 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1953 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1108 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line146 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2199 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1144 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1941 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line909 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2012 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1790 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line41 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1995 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line30 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1505 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1149 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2113 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line437 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1643 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1537 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1352 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2000 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1736 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line671 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line738 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2289 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1594 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line436 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line70 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2067 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line784 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1574 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1688 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1758 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2287 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1115 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line530 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1696 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1113 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line774 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2341 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line642 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1625 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1752 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2075 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line888 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1552 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1370 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# Excessive output truncated after 524804 bytes.┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2226 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1181 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2273 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2029 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2222 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1482 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2106 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1840 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line780 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line643 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1019 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1037 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1991 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line19 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1783 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1956 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# 128×5 DataFrame
#  Row │ network     feeder    buses  loads  branches
#      │ String      String    Int64  Int64  Int64
# ─────┼──────────────────────────────────────────────
#    1 │ Network_14  Feeder_1   2349     72      2349
#    2 │ Network_14  Feeder_2    108     28       108
#    3 │ Network_14  Feeder_3    156     60       156
#    4 │ Network_14  Feeder_4   1795     68      1795
#    5 │ Network_14  Feeder_5    145     45       145
#    6 │ Network_14  Feeder_6    176     44       176
#    7 │ Network_24  Feeder_1   1076     56      1076
#    8 │ Network_24  Feeder_2   1694     79      1694
#    9 │ Network_8   Feeder_1   2068     52      2068
#   10 │ Network_8   Feeder_2   7023    302      7023
#   11 │ network_1   Feeder_1    907     55       907
#   ⋮  │     ⋮          ⋮        ⋮      ⋮       ⋮
#  119 │ network_7   Feeder_4   1545    186      1545
#  120 │ network_7   Feeder_5    472     61       472
#  121 │ network_7   Feeder_6    216     23       216
#  122 │ network_7   Feeder_7    349     22       349
#  123 │ network_9   Feeder_1   2496     85      2496
#  124 │ network_9   Feeder_2    112     21       112
#  125 │ network_9   Feeder_3    107     20       107
#  126 │ network_9   Feeder_4    140     21       140
#  127 │ network_9   Feeder_5   3590    124      3590
#  128 │ network_9   Feeder_6    206     22       206
#                                     107 rows omitted

# %%
sort(results, :buses)
# Out:
# 128×5 DataFrame
#  Row │ network     feeder    buses  loads  branches
#      │ String      String    Int64  Int64  Int64
# ─────┼──────────────────────────────────────────────
#    1 │ network_23  Feeder_3     59      2        59
#    2 │ network_20  Feeder_5     65     23        65
#    3 │ network_20  Feeder_4     71     29        71
#    4 │ network_20  Feeder_1     78     25        78
#    5 │ network_9   Feeder_3    107     20       107
#    6 │ Network_14  Feeder_2    108     28       108
#    7 │ network_13  Feeder_3    108      2       108
#    8 │ network_9   Feeder_2    112     21       112
#    9 │ network_5   Feeder_1    131      4       131
#   10 │ network_9   Feeder_4    140     21       140
#   11 │ Network_14  Feeder_5    145     45       145
#   ⋮  │     ⋮          ⋮        ⋮      ⋮       ⋮
#  119 │ network_15  Feeder_2   2753    107      2753
#  120 │ network_17  Feeder_1   2843    188      2843
#  121 │ network_5   Feeder_3   2903    156      2903
#  122 │ network_12  Feeder_1   3156    157      3156
#  123 │ network_6   Feeder_1   3316    117      3316
#  124 │ network_9   Feeder_5   3590    124      3590
#  125 │ network_17  Feeder_6   3856    223      3856
#  126 │ network_15  Feeder_3   4080    169      4080
#  127 │ network_15  Feeder_4   4769    138      4769
#  128 │ Network_8   Feeder_2   7023    302      7023
#                                     107 rows omitted

# %%
small = filter(r -> r.buses ≤ 150 && r.loads ≥ 10, results)
sort(small, :buses)
# Out:
# 8×5 DataFrame
#  Row │ network     feeder    buses  loads  branches
#      │ String      String    Int64  Int64  Int64
# ─────┼──────────────────────────────────────────────
#    1 │ network_20  Feeder_5     65     23        65
#    2 │ network_20  Feeder_4     71     29        71
#    3 │ network_20  Feeder_1     78     25        78
#    4 │ network_9   Feeder_3    107     20       107
#    5 │ Network_14  Feeder_2    108     28       108
#    6 │ network_9   Feeder_2    112     21       112
#    7 │ network_9   Feeder_4    140     21       140
#    8 │ Network_14  Feeder_5    145     45       145

# %% [markdown]
# ### Selected feeder:
# - Network: network_20
# - Feeder: Feeder_5
# - Buses: 65
# - Loads: 23
# >Reason: small, radial, suitable for intuition-building

# %% [markdown]
# ## Screening – Three-wire Kron-reduced feeders

# %% [markdown]
# Due to current PowerModelsDistribution limitations in solving
# grounded four-wire LV feeders, screening is repeated using the
# three-wire Kron-reduced representation of the CSIRO dataset.
#
# This representation preserves feeder topology and loading,
# while enabling stable power flow and OPF simulations.

# %%
using PowerModelsDistribution
using DataFrames

BASE_DIR_3W = joinpath("..", "data", "Three-wire-Kron-reduced")

results_3w = DataFrame(
    network = String[],
    feeder = String[],
    buses = Int[],
    loads = Int[],
    branches = Int[]
)

for net in sort(readdir(BASE_DIR_3W))
    net_path = joinpath(BASE_DIR_3W, net)
    isdir(net_path) || continue

    for feeder in sort(readdir(net_path))
        feeder_path = joinpath(net_path, feeder)
        master = joinpath(feeder_path, "Master.dss")

        isfile(master) || continue

        try
            pm = PowerModelsDistribution.parse_file(master)

            n_buses = length(pm["bus"])
            n_loads = haskey(pm, "load") ? length(pm["load"]) : 0
            n_lines = haskey(pm, "line") ? length(pm["line"]) : 0
            n_transformers = haskey(pm, "transformer") ? length(pm["transformer"]) : 0

            push!(results_3w, (
                net,
                feeder,
                n_buses,
                n_loads,
                n_lines + n_transformers
            ))
        catch
            @warn "Failed to load $net / $feeder"
        end
    end
end

results_3w
# Out:
# [ PowerModelsDistribution | Info ] : Circuit has been reset with the 'clear' on line 18 in 'Master.dss'
# [ PowerModelsDistribution | Info ] : Redirecting to 'linecode.txt' on line 22 in 'Master.dss'
# [ PowerModelsDistribution | Info ] : Redirecting to 'lines.txt' on line 23 in 'LineCode.txt'
# [ PowerModelsDistribution | Info ] : Redirecting to 'loads.txt' on line 24 in 'Lines.txt'
# [ PowerModelsDistribution | Info ] : Command 'solve' on line 29 in 'Master.dss' is not supported, skipping.
# [ PowerModelsDistribution | Info ] : Command 'closedi' on line 30 in 'Master.dss' is not supported, skipping.
# [ PowerModelsDistribution | Info ] : basemva=100 is the default value, you may want to adjust sbase_default for better convergence
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line865 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line617 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line991 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line821 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line722 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line120 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line330 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line902 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1764 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1214 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line535 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1066 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1890 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2115 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2249 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1631 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2274 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1515 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2096 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line929 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line698 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line551 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line830 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1755 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2217 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line329 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2313 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1332 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1215 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line117 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line851 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1433 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2187 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1884 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line470 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2089 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1516 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line502 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1389 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1342 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2345 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2051 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line609 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line992 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1083 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1413 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2259 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1345 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line736 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line947 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2330 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2335 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1446 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1281 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line537 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line242 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1720 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1473 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1938 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2201 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1173 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1363 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1578 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1621 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line298 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line639 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line428 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line608 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1056 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1053 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line733 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2198 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line83 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1331 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1408 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1564 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line247 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line548 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1989 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line13 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line213 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line709 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2046 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line440 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2175 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line496 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line974 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line122 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line876 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line423 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line871 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1699 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2047 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2050 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line232 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1065 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1189 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1550 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line529 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1999 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2154 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line840 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1097 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line158 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1701 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1439 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line21 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1543 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1958 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line373 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line7 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line74 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line514 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line751 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1480 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line142 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1945 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1226 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1723 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1080 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1330 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2191 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line151 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1217 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1911 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1293 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1635 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1601 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line143 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line636 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line670 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line342 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1444 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1964 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2232 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line652 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line403 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line462 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line301 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line626 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line846 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1245 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2302 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line766 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2058 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1423 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1287 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line261 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line930 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line64 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2334 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1016 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2347 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1659 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line315 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line385 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1494 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line605 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line188 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1429 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1882 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2136 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2270 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2056 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line799 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line625 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1848 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2337 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1808 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line132 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line45 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1919 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1170 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1365 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line490 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1367 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line228 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1910 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1007 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1642 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line664 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line572 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1375 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line538 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line591 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line159 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line906 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1121 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1749 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line383 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1602 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2262 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line260 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2214 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2040 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line895 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1055 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line898 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line850 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line760 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line925 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1166 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1852 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2304 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line238 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line172 does not match circuit basefreq=50.0
# ...
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line881 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1953 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1108 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line146 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2199 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1144 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1941 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line909 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2012 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1790 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line41 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1995 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line30 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1505 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1149 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2113 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line437 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1643 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1537 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1352 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2000 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1736 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line671 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line738 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2289 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1594 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line436 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line70 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2067 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line784 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1574 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1688 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1758 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2287 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1115 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line530 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1696 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1113 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line774 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2341 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line642 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1625 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1752 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2075 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line888 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1552 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1370 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2226 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1181 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2273 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2029 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2222 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1482 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2106 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1840 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line780 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line643 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# Excessive output truncated after 524804 bytes.┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1019 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1037 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1991 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line19 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1783 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1956 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# 128×5 DataFrame
#  Row │ network     feeder    buses  loads  branches
#      │ String      String    Int64  Int64  Int64
# ─────┼──────────────────────────────────────────────
#    1 │ Network_14  Feeder_1   2349     72      2348
#    2 │ Network_14  Feeder_2    108     28       107
#    3 │ Network_14  Feeder_3    156     60       155
#    4 │ Network_14  Feeder_4   1795     68      1794
#    5 │ Network_14  Feeder_5    145     45       144
#    6 │ Network_14  Feeder_6    176     44       175
#    7 │ Network_24  Feeder_1   1076     56      1075
#    8 │ Network_24  Feeder_2   1694     79      1693
#    9 │ Network_8   Feeder_1   2068     52      2067
#   10 │ Network_8   Feeder_2   7023    302      7022
#   11 │ network_1   Feeder_1    907     55       906
#   ⋮  │     ⋮          ⋮        ⋮      ⋮       ⋮
#  119 │ network_7   Feeder_4   1545    186      1544
#  120 │ network_7   Feeder_5    472     61       471
#  121 │ network_7   Feeder_6    216     23       215
#  122 │ network_7   Feeder_7    349     22       348
#  123 │ network_9   Feeder_1   2496     85      2495
#  124 │ network_9   Feeder_2    112     21       111
#  125 │ network_9   Feeder_3    107     20       106
#  126 │ network_9   Feeder_4    140     21       139
#  127 │ network_9   Feeder_5   3590    124      3589
#  128 │ network_9   Feeder_6    206     22       205
#                                     107 rows omitted

# %%
sort(results_3w, :buses)
# Out:
# 128×5 DataFrame
#  Row │ network     feeder    buses  loads  branches
#      │ String      String    Int64  Int64  Int64
# ─────┼──────────────────────────────────────────────
#    1 │ network_23  Feeder_3     59      2        58
#    2 │ network_20  Feeder_5     65     23        64
#    3 │ network_20  Feeder_4     71     29        70
#    4 │ network_20  Feeder_1     78     25        77
#    5 │ network_9   Feeder_3    107     20       106
#    6 │ Network_14  Feeder_2    108     28       107
#    7 │ network_13  Feeder_3    108      2       107
#    8 │ network_9   Feeder_2    112     21       111
#    9 │ network_5   Feeder_1    131      4       130
#   10 │ network_9   Feeder_4    140     21       139
#   11 │ Network_14  Feeder_5    145     45       144
#   ⋮  │     ⋮          ⋮        ⋮      ⋮       ⋮
#  119 │ network_15  Feeder_2   2753    107      2752
#  120 │ network_17  Feeder_1   2843    188      2842
#  121 │ network_5   Feeder_3   2903    156      2902
#  122 │ network_12  Feeder_1   3156    157      3155
#  123 │ network_6   Feeder_1   3316    117      3315
#  124 │ network_9   Feeder_5   3590    124      3589
#  125 │ network_17  Feeder_6   3856    223      3855
#  126 │ network_15  Feeder_3   4080    169      4079
#  127 │ network_15  Feeder_4   4769    138      4768
#  128 │ Network_8   Feeder_2   7023    302      7022
#                                     107 rows omitted

# %%
small_3W = filter(r -> r.buses ≤ 150 && r.loads ≥ 10, results_3w)
sort(small_3W, :buses)
# Out:
# 8×5 DataFrame
#  Row │ network     feeder    buses  loads  branches
#      │ String      String    Int64  Int64  Int64
# ─────┼──────────────────────────────────────────────
#    1 │ network_20  Feeder_5     65     23        64
#    2 │ network_20  Feeder_4     71     29        70
#    3 │ network_20  Feeder_1     78     25        77
#    4 │ network_9   Feeder_3    107     20       106
#    5 │ Network_14  Feeder_2    108     28       107
#    6 │ network_9   Feeder_2    112     21       111
#    7 │ network_9   Feeder_4    140     21       139
#    8 │ Network_14  Feeder_5    145     45       144

# %% [markdown]
# ## Screening – Three-wire phase-to-neutral feeders

# %% [markdown]
# Due to current limitations in PowerModelsDistribution when solving
# grounded four-wire LV feeders, network screening is performed using
# the **three-wire phase-to-neutral (Kron-reduced) representation** of
# the CSIRO dataset.
#
# This representation:
# - preserves the original feeder topology and load placement,
# - embeds the neutral conductor’s effect into the phase impedances,
# - enables stable and repeatable power flow and OPF simulations.
#
# All feeders selected in this step are therefore suitable for baseline
# and scenario analysis.

# %%
using PowerModelsDistribution
using DataFrames

BASE_DIR_3W_PH = joinpath("..", "data", "Three-wire-phase-to-neutral")

results_3w_ph = DataFrame(
    network = String[],
    feeder = String[],
    buses = Int[],
    loads = Int[],
    branches = Int[]
)

for net in sort(readdir(BASE_DIR_3W_PH))
    net_path = joinpath(BASE_DIR_3W_PH, net)
    isdir(net_path) || continue

    for feeder in sort(readdir(net_path))
        feeder_path = joinpath(net_path, feeder)
        master = joinpath(feeder_path, "Master.dss")

        isfile(master) || continue

        try
            pm_3w_ph = PowerModelsDistribution.parse_file(master)

            n_buses = length(pm_3w_ph["bus"])
            n_loads = haskey(pm_3w_ph, "load") ? length(pm_3w_ph["load"]) : 0
            n_lines = haskey(pm_3w_ph, "line") ? length(pm_3w_ph["line"]) : 0
            n_transformers = haskey(pm_3w_ph, "transformer") ? length(pm_3w_ph["transformer"]) : 0

            push!(results_3w_ph, (
                net,
                feeder,
                n_buses,
                n_loads,
                n_lines + n_transformers
            ))
        catch
            @warn "Failed to load $net / $feeder"
        end
    end
end

results_3w_ph
# Out:
# [ PowerModelsDistribution | Info ] : Circuit has been reset with the 'clear' on line 18 in 'Master.dss'
# [ PowerModelsDistribution | Info ] : Redirecting to 'linecode.txt' on line 22 in 'Master.dss'
# [ PowerModelsDistribution | Info ] : Redirecting to 'lines.txt' on line 23 in 'LineCode.txt'
# [ PowerModelsDistribution | Info ] : Redirecting to 'loads.txt' on line 24 in 'Lines.txt'
# [ PowerModelsDistribution | Info ] : Command 'solve' on line 29 in 'Master.dss' is not supported, skipping.
# [ PowerModelsDistribution | Info ] : Command 'closedi' on line 30 in 'Master.dss' is not supported, skipping.
# [ PowerModelsDistribution | Info ] : basemva=100 is the default value, you may want to adjust sbase_default for better convergence
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line865 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line617 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line991 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line821 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line722 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line120 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line330 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line902 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1764 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1214 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line535 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1066 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1890 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2115 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2249 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1631 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2274 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1515 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2096 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line929 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line698 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line551 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line830 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1755 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2217 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line329 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2313 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1332 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1215 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line117 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line851 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1433 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2187 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1884 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line470 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2089 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1516 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line502 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1389 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1342 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2345 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2051 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line609 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line992 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1083 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1413 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2259 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1345 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line736 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line947 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2330 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2335 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1446 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1281 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line537 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line242 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1720 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1473 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1938 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2201 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1173 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1363 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1578 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1621 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line298 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line639 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line428 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line608 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1056 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1053 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line733 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2198 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line83 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1331 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1408 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1564 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line247 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line548 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1989 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line13 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line213 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line709 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2046 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line440 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2175 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line496 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line974 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line122 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line876 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line423 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line871 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1699 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2047 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2050 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line232 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1065 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1189 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1550 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line529 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1999 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2154 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line840 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1097 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line158 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1701 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1439 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line21 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1543 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1958 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line373 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line7 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line74 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line514 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line751 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1480 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line142 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1945 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1226 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1723 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1080 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1330 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2191 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line151 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1217 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1911 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1293 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1635 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1601 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line143 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line636 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line670 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line342 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1444 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1964 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2232 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line652 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line403 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line462 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line301 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line626 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line846 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1245 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2302 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line766 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2058 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1423 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1287 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line261 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line930 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line64 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2334 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1016 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2347 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1659 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line315 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line385 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1494 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line605 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line188 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1429 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1882 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2136 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2270 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2056 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line799 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line625 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1848 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2337 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1808 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line132 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line45 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1919 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1170 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1365 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line490 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1367 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line228 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1910 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1007 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1642 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line664 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line572 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1375 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line538 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line591 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line159 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line906 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1121 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1749 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line383 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1602 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2262 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line260 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2214 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2040 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line895 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1055 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line898 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line850 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line760 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line925 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1166 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1852 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2304 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line238 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line172 does not match circuit basefreq=50.0
# ...
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line881 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1953 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1108 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line146 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2199 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1144 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1941 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line909 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2012 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1790 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line41 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1995 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line30 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1505 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1149 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2113 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line437 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1643 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1537 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1352 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2000 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1736 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line671 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line738 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2289 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1594 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line436 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line70 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2067 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line784 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1574 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1688 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1758 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2287 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1115 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line530 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1696 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# Excessive output truncated after 524804 bytes.┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1113 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line774 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2341 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line642 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1625 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1752 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2075 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line888 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1552 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1370 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2226 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1181 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2273 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2029 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2222 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1482 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line2106 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1840 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line780 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line643 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1019 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1037 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1991 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line19 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1783 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# ┌ PowerModelsDistribution | Warning ] : basefreq=60.0 on line.line1956 does not match circuit basefreq=50.0
# └ @ PowerModelsDistribution ~/.julia/packages/PowerModelsDistribution/EOTxp/src/data_model/transformations/dss2eng.jl:422
# 128×5 DataFrame
#  Row │ network     feeder    buses  loads  branches
#      │ String      String    Int64  Int64  Int64
# ─────┼──────────────────────────────────────────────
#    1 │ Network_14  Feeder_1   2349     72      2348
#    2 │ Network_14  Feeder_2    108     28       107
#    3 │ Network_14  Feeder_3    156     60       155
#    4 │ Network_14  Feeder_4   1795     68      1794
#    5 │ Network_14  Feeder_5    145     45       144
#    6 │ Network_14  Feeder_6    176     44       175
#    7 │ Network_24  Feeder_1   1076     56      1075
#    8 │ Network_24  Feeder_2   1694     79      1693
#    9 │ Network_8   Feeder_1   2068     52      2067
#   10 │ Network_8   Feeder_2   7023    302      7022
#   11 │ network_1   Feeder_1    907     55       906
#   ⋮  │     ⋮          ⋮        ⋮      ⋮       ⋮
#  119 │ network_7   Feeder_4   1545    186      1544
#  120 │ network_7   Feeder_5    472     61       471
#  121 │ network_7   Feeder_6    216     23       215
#  122 │ network_7   Feeder_7    349     22       348
#  123 │ network_9   Feeder_1   2496     85      2495
#  124 │ network_9   Feeder_2    112     21       111
#  125 │ network_9   Feeder_3    107     20       106
#  126 │ network_9   Feeder_4    140     21       139
#  127 │ network_9   Feeder_5   3590    124      3589
#  128 │ network_9   Feeder_6    206     22       205
#                                     107 rows omitted

# %%
sort(results_3w_ph, :buses)
# Out:
# 128×5 DataFrame
#  Row │ network     feeder    buses  loads  branches
#      │ String      String    Int64  Int64  Int64
# ─────┼──────────────────────────────────────────────
#    1 │ network_23  Feeder_3     59      2        58
#    2 │ network_20  Feeder_5     65     23        64
#    3 │ network_20  Feeder_4     71     29        70
#    4 │ network_20  Feeder_1     78     25        77
#    5 │ network_9   Feeder_3    107     20       106
#    6 │ Network_14  Feeder_2    108     28       107
#    7 │ network_13  Feeder_3    108      2       107
#    8 │ network_9   Feeder_2    112     21       111
#    9 │ network_5   Feeder_1    131      4       130
#   10 │ network_9   Feeder_4    140     21       139
#   11 │ Network_14  Feeder_5    145     45       144
#   ⋮  │     ⋮          ⋮        ⋮      ⋮       ⋮
#  119 │ network_15  Feeder_2   2753    107      2752
#  120 │ network_17  Feeder_1   2843    188      2842
#  121 │ network_5   Feeder_3   2903    156      2902
#  122 │ network_12  Feeder_1   3156    157      3155
#  123 │ network_6   Feeder_1   3316    117      3315
#  124 │ network_9   Feeder_5   3590    124      3589
#  125 │ network_17  Feeder_6   3856    223      3855
#  126 │ network_15  Feeder_3   4080    169      4079
#  127 │ network_15  Feeder_4   4769    138      4768
#  128 │ Network_8   Feeder_2   7023    302      7022
#                                     107 rows omitted

# %%
small_3w_ph = filter(r -> r.buses ≤ 150 && r.loads ≥ 10, results_3w_ph)
sort(small_3w_ph, :buses)
# Out:
# 8×5 DataFrame
#  Row │ network     feeder    buses  loads  branches
#      │ String      String    Int64  Int64  Int64
# ─────┼──────────────────────────────────────────────
#    1 │ network_20  Feeder_5     65     23        64
#    2 │ network_20  Feeder_4     71     29        70
#    3 │ network_20  Feeder_1     78     25        77
#    4 │ network_9   Feeder_3    107     20       106
#    5 │ Network_14  Feeder_2    108     28       107
#    6 │ network_9   Feeder_2    112     21       111
#    7 │ network_9   Feeder_4    140     21       139
#    8 │ Network_14  Feeder_5    145     45       144

# %% [markdown]
# ### Screening results – candidate three-wire feeders
#
# The three-wire phase-to-neutral CSIRO feeders were screened to identify
# a **manageable but representative LV network** for baseline analysis.
#
# Selection criteria:
# - fewer than 150 buses (to keep simulations tractable),
# - more than 10 loads (to ensure meaningful voltage and loading behaviour).
#
# This resulted in the following candidate feeders.
